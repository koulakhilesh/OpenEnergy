# %% [markdown]
# # Forecast Price Model
#
# This notebook is designed to forecast energy prices using the `ForecastPriceModel` class.
# The model is trained on historical data from 2018 and then used to predict prices for a specific date.
# The actual prices for that date are then compared with the forecasted prices.

# %%
# Import necessary libraries
from datetime import datetime
import os
import sys
import matplotlib.pyplot as plt

# Set up module path
module_path = os.path.abspath(os.path.join('../../'))
if module_path not in sys.path:
    sys.path.append(module_path)

# Import project-specific libraries
from scripts.prices import ForecastPriceModel
from scripts.shared import CSVDataProvider
from scripts.forecast import FeatureEngineer, XGBModel

IMAGE_SAVING_LOCATION = os.path.join(module_path, 'images','notebook','prices')
MODEL_LOCATION = os.path.join(module_path, 'models','prices')

# %%
# Load and prepare data
csv_file_path = os.path.join(module_path, "data", "time_series", "time_series_60min_singleindex_filtered.csv")
data_provider = CSVDataProvider(csv_file_path)
data = data_provider.get_data(column_names=["GB_GBN_price_day_ahead"],timestamp_column="utc_timestamp")

# Initialize feature engineer
feature_engineer = FeatureEngineer()

# Load Model
params = {'random_state': 42, "n_estimators": 1000, "max_depth": 6, "learning_rate": 0.1, "objective": "reg:squarederror"}
model=XGBModel(params)

# Train the forecast model
forecaster = ForecastPriceModel(data_provider=data_provider, feature_engineer=feature_engineer, model=model)
train_data = data[data.index.year.isin([2016, 2017, 2018])]
train_data["GB_GBN_price_day_ahead"].interpolate(method="linear", inplace=True)
print(train_data.isna().sum())
forecaster.train(train_data)
# Out:
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\prices\forecasted_price.py:65: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   self.data[self.PRICE_COLUMN].interpolate(method="linear", inplace=True)
# C:\Users\koula\AppData\Local\Temp\ipykernel_20724\2484807568.py:16: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_data["GB_GBN_price_day_ahead"].interpolate(method="linear", inplace=True)
# C:\Users\koula\AppData\Local\Temp\ipykernel_20724\2484807568.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data["GB_GBN_price_day_ahead"].interpolate(method="linear", inplace=True)
# GB_GBN_price_day_ahead    0
# dtype: int64
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lag_{i}"] = df[column_name].shift(i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:162: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lead_{i}"] = df[column_name].shift(-i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:162: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lead_{i}"] = df[column_name].shift(-i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:162: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lead_{i}"] = df[column_name].shift(-i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:162: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lead_{i}"] = df[column_name].shift(-i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:162: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lead_{i}"] = df[column_name].shift(-i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:162: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lead_{i}"] = df[column_name].shift(-i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:162: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lead_{i}"] = df[column_name].shift(-i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:162: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lead_{i}"] = df[column_name].shift(-i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:162: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lead_{i}"] = df[column_name].shift(-i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:162: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lead_{i}"] = df[column_name].shift(-i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:162: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lead_{i}"] = df[column_name].shift(-i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:162: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lead_{i}"] = df[column_name].shift(-i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:162: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lead_{i}"] = df[column_name].shift(-i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:162: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lead_{i}"] = df[column_name].shift(-i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:162: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lead_{i}"] = df[column_name].shift(-i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:162: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lead_{i}"] = df[column_name].shift(-i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:162: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lead_{i}"] = df[column_name].shift(-i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:162: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lead_{i}"] = df[column_name].shift(-i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:162: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lead_{i}"] = df[column_name].shift(-i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:162: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lead_{i}"] = df[column_name].shift(-i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:162: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lead_{i}"] = df[column_name].shift(-i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:162: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lead_{i}"] = df[column_name].shift(-i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:162: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lead_{i}"] = df[column_name].shift(-i)
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:162: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f"{column_name}_lead_{i}"] = df[column_name].shift(-i)
#   0%|          | 0/24 [00:00<?, ?it/s]
# [0]	validation_0-rmse:26.76673
# c:\Users\koula\miniconda3\envs\OpenEnergy\lib\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [100]	validation_0-rmse:15.93188
# [200]	validation_0-rmse:15.89164
# [300]	validation_0-rmse:15.87636
# [400]	validation_0-rmse:15.86790
# [500]	validation_0-rmse:15.86052
# [600]	validation_0-rmse:15.85111
# [700]	validation_0-rmse:15.85049
# [753]	validation_0-rmse:15.85225
# [0]	validation_0-rmse:24.81328
# [100]	validation_0-rmse:16.53083
# [200]	validation_0-rmse:16.38652
# [300]	validation_0-rmse:16.36489
# [400]	validation_0-rmse:16.33740
# [481]	validation_0-rmse:16.34107
# [0]	validation_0-rmse:25.63589
# [100]	validation_0-rmse:16.22798
# [200]	validation_0-rmse:16.03423
# [300]	validation_0-rmse:15.96478
# [400]	validation_0-rmse:15.93508
# [500]	validation_0-rmse:15.92390
# [535]	validation_0-rmse:15.92627
# [0]	validation_0-rmse:23.53553
# [100]	validation_0-rmse:15.61197
# [200]	validation_0-rmse:15.38184
# [300]	validation_0-rmse:15.32540
# [400]	validation_0-rmse:15.29876
# [500]	validation_0-rmse:15.27414
# [600]	validation_0-rmse:15.26408
# [700]	validation_0-rmse:15.25457
# [800]	validation_0-rmse:15.25086
# [900]	validation_0-rmse:15.24734
# [978]	validation_0-rmse:15.24737
# [0]	validation_0-rmse:21.75088
# [100]	validation_0-rmse:12.02882
# [200]	validation_0-rmse:11.86135
# [300]	validation_0-rmse:11.79979
# [400]	validation_0-rmse:11.77128
# [500]	validation_0-rmse:11.75558
# [600]	validation_0-rmse:11.73625
# [700]	validation_0-rmse:11.72711
# [800]	validation_0-rmse:11.71552
# [900]	validation_0-rmse:11.71156
# [999]	validation_0-rmse:11.70817
# [0]	validation_0-rmse:20.31021
# [100]	validation_0-rmse:9.92324
# [200]	validation_0-rmse:9.68151
# [300]	validation_0-rmse:9.59645
# [400]	validation_0-rmse:9.53987
# [500]	validation_0-rmse:9.50851
# [600]	validation_0-rmse:9.49133
# [700]	validation_0-rmse:9.47636
# [800]	validation_0-rmse:9.46387
# [900]	validation_0-rmse:9.45735
# [999]	validation_0-rmse:9.45216
# [0]	validation_0-rmse:17.29263
# [100]	validation_0-rmse:8.07548
# [200]	validation_0-rmse:7.79918
# [300]	validation_0-rmse:7.70308
# [400]	validation_0-rmse:7.64694
# [500]	validation_0-rmse:7.60347
# [600]	validation_0-rmse:7.57263
# [700]	validation_0-rmse:7.54713
# [800]	validation_0-rmse:7.53298
# [900]	validation_0-rmse:7.52560
# [999]	validation_0-rmse:7.52058
# [0]	validation_0-rmse:20.98851
# [100]	validation_0-rmse:13.05849
# [200]	validation_0-rmse:12.82833
# [300]	validation_0-rmse:12.75752
# [400]	validation_0-rmse:12.72423
# [500]	validation_0-rmse:12.69834
# [600]	validation_0-rmse:12.67195
# [700]	validation_0-rmse:12.65816
# [800]	validation_0-rmse:12.64916
# [900]	validation_0-rmse:12.64011
# [999]	validation_0-rmse:12.63278
# [0]	validation_0-rmse:19.87111
# [100]	validation_0-rmse:12.37560
# [200]	validation_0-rmse:12.19895
# [300]	validation_0-rmse:12.13158
# [400]	validation_0-rmse:12.07844
# [500]	validation_0-rmse:12.05267
# [600]	validation_0-rmse:12.04346
# [700]	validation_0-rmse:12.03401
# [800]	validation_0-rmse:12.02499
# [900]	validation_0-rmse:12.02170
# [999]	validation_0-rmse:12.01845
# [0]	validation_0-rmse:21.43124
# [100]	validation_0-rmse:14.33391
# [200]	validation_0-rmse:14.15303
# [300]	validation_0-rmse:14.05599
# [400]	validation_0-rmse:14.02035
# [500]	validation_0-rmse:14.00014
# [600]	validation_0-rmse:13.99315
# [700]	validation_0-rmse:13.98279
# [800]	validation_0-rmse:13.97465
# [900]	validation_0-rmse:13.97064
# [999]	validation_0-rmse:13.96757
# [0]	validation_0-rmse:23.11503
# [100]	validation_0-rmse:14.05454
# [200]	validation_0-rmse:13.80404
# [300]	validation_0-rmse:13.69685
# [400]	validation_0-rmse:13.65190
# [500]	validation_0-rmse:13.62655
# [600]	validation_0-rmse:13.60728
# [700]	validation_0-rmse:13.60112
# [800]	validation_0-rmse:13.59378
# [900]	validation_0-rmse:13.58815
# [999]	validation_0-rmse:13.58544
# [0]	validation_0-rmse:25.08510
# [100]	validation_0-rmse:18.02986
# [200]	validation_0-rmse:17.85730
# [300]	validation_0-rmse:17.82701
# [400]	validation_0-rmse:17.79790
# [500]	validation_0-rmse:17.78044
# [600]	validation_0-rmse:17.77664
# [700]	validation_0-rmse:17.76192
# [800]	validation_0-rmse:17.75551
# [900]	validation_0-rmse:17.75262
# [999]	validation_0-rmse:17.74902
# [0]	validation_0-rmse:24.81085
# [100]	validation_0-rmse:15.38379
# [200]	validation_0-rmse:15.20688
# [300]	validation_0-rmse:15.16289
# [400]	validation_0-rmse:15.13073
# [500]	validation_0-rmse:15.10371
# [600]	validation_0-rmse:15.09317
# [700]	validation_0-rmse:15.07762
# [800]	validation_0-rmse:15.07433
# [900]	validation_0-rmse:15.07363
# [999]	validation_0-rmse:15.07303
# [0]	validation_0-rmse:22.54540
# [100]	validation_0-rmse:12.37095
# [200]	validation_0-rmse:12.16166
# [300]	validation_0-rmse:12.07412
# [400]	validation_0-rmse:12.03881
# [500]	validation_0-rmse:12.00151
# [600]	validation_0-rmse:11.98501
# [700]	validation_0-rmse:11.96712
# [800]	validation_0-rmse:11.95325
# [900]	validation_0-rmse:11.94775
# [999]	validation_0-rmse:11.94528
# [0]	validation_0-rmse:18.50709
# [100]	validation_0-rmse:14.94912
# [200]	validation_0-rmse:14.79114
# [300]	validation_0-rmse:14.78671
# [352]	validation_0-rmse:14.77050
# [0]	validation_0-rmse:22.33457
# [100]	validation_0-rmse:15.64662
# [200]	validation_0-rmse:15.46822
# [300]	validation_0-rmse:15.39908
# [400]	validation_0-rmse:15.37477
# [500]	validation_0-rmse:15.35545
# [600]	validation_0-rmse:15.34108
# [700]	validation_0-rmse:15.33074
# [800]	validation_0-rmse:15.32761
# [855]	validation_0-rmse:15.32889
# [0]	validation_0-rmse:18.91369
# [100]	validation_0-rmse:10.37415
# [200]	validation_0-rmse:10.14753
# [300]	validation_0-rmse:10.06853
# [400]	validation_0-rmse:10.02123
# [500]	validation_0-rmse:9.97279
# [600]	validation_0-rmse:9.94516
# [700]	validation_0-rmse:9.92946
# [800]	validation_0-rmse:9.91567
# [900]	validation_0-rmse:9.91003
# [999]	validation_0-rmse:9.90080
# [0]	validation_0-rmse:17.41598
# [100]	validation_0-rmse:9.15129
# [130]	validation_0-rmse:9.07473
# [0]	validation_0-rmse:18.91534
# [100]	validation_0-rmse:11.75856
# [200]	validation_0-rmse:11.54191
# [300]	validation_0-rmse:11.45910
# [400]	validation_0-rmse:11.39409
# [500]	validation_0-rmse:11.37240
# [600]	validation_0-rmse:11.35372
# [700]	validation_0-rmse:11.34391
# [800]	validation_0-rmse:11.33763
# [900]	validation_0-rmse:11.33195
# [999]	validation_0-rmse:11.32827
# [0]	validation_0-rmse:22.14579
# [100]	validation_0-rmse:11.77441
# [200]	validation_0-rmse:11.54837
# [300]	validation_0-rmse:11.49216
# [400]	validation_0-rmse:11.45057
# [500]	validation_0-rmse:11.43905
# [600]	validation_0-rmse:11.41142
# [700]	validation_0-rmse:11.40075
# [800]	validation_0-rmse:11.39665
# [900]	validation_0-rmse:11.39004
# [999]	validation_0-rmse:11.39097
# [0]	validation_0-rmse:24.10436
# [100]	validation_0-rmse:16.96289
# [200]	validation_0-rmse:16.74181
# [300]	validation_0-rmse:16.65002
# [400]	validation_0-rmse:16.62214
# [500]	validation_0-rmse:16.58939
# [600]	validation_0-rmse:16.58583
# [700]	validation_0-rmse:16.57672
# [800]	validation_0-rmse:16.56567
# [900]	validation_0-rmse:16.55948
# [999]	validation_0-rmse:16.55555
# [0]	validation_0-rmse:15.83356
# [100]	validation_0-rmse:9.33014
# [200]	validation_0-rmse:9.13374
# [300]	validation_0-rmse:9.05833
# [400]	validation_0-rmse:9.01122
# [500]	validation_0-rmse:8.97230
# [600]	validation_0-rmse:8.95051
# [700]	validation_0-rmse:8.93778
# [800]	validation_0-rmse:8.93059
# [900]	validation_0-rmse:8.92122
# [999]	validation_0-rmse:8.91419
# [0]	validation_0-rmse:23.20916
# [100]	validation_0-rmse:15.83912
# [200]	validation_0-rmse:15.68569
# [300]	validation_0-rmse:15.61078
# [400]	validation_0-rmse:15.56833
# [500]	validation_0-rmse:15.54132
# [600]	validation_0-rmse:15.53672
# [700]	validation_0-rmse:15.52098
# [800]	validation_0-rmse:15.50846
# [899]	validation_0-rmse:15.50961
# [0]	validation_0-rmse:20.66892
# [100]	validation_0-rmse:12.04311
# [200]	validation_0-rmse:11.88466
# [300]	validation_0-rmse:11.83350
# [400]	validation_0-rmse:11.79764
# [500]	validation_0-rmse:11.78338
# [600]	validation_0-rmse:11.76624
# [700]	validation_0-rmse:11.75111
# [800]	validation_0-rmse:11.74077
# [900]	validation_0-rmse:11.73196
# [999]	validation_0-rmse:11.72779
# Validation MSE: 178.20661867311347

# %%
# Save the model
MODEL_NAME = "price_forecast_model.pkl"
forecaster.save_model(os.path.join(MODEL_LOCATION, MODEL_NAME))

# %%
# Load the model
model = ForecastPriceModel.load_model(os.path.join(MODEL_LOCATION, MODEL_NAME))
pretrained_forecaster = ForecastPriceModel(data_provider=data_provider, feature_engineer=feature_engineer, model=model)
# Out:
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\prices\forecasted_price.py:65: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   self.data[self.PRICE_COLUMN].interpolate(method="linear", inplace=True)

# %%
# Get forecasted prices
forecasted_prices, prices_current_date = pretrained_forecaster.get_prices(datetime(2019, 1, 1))

# Plot the actual values and the forecast
plt.figure(figsize=(10, 6))
plt.plot(prices_current_date, label='Actual')
plt.plot(forecasted_prices, label='Forecast')
plt.title('Forecast vs Actual')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.savefig(os.path.join(IMAGE_SAVING_LOCATION, 'forecast_vs_actual.png'))
plt.show()
# Out:
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\forecast\ts_forecast.py:155: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   - df (pandas.DataFrame): The input DataFrame.

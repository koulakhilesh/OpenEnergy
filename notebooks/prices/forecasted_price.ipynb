# %% [markdown]
# # Forecast Price Model
#
# This notebook is designed to forecast energy prices using the `ForecastPriceModel` class.
# The model is trained on historical data from 2018 and then used to predict prices for a specific date.
# The actual prices for that date are then compared with the forecasted prices.

# %%
# Import necessary libraries
from datetime import datetime
import os
import sys
import matplotlib.pyplot as plt

# Set up module path
module_path = os.path.abspath(os.path.join('../../'))
if module_path not in sys.path:
    sys.path.append(module_path)

# Import project-specific libraries
from scripts.prices import ForecastPriceModel
from scripts.shared import CSVDataProvider
from scripts.forecast import FeatureEngineer, XGBModel

IMAGE_SAVING_LOCATION = os.path.join(module_path, 'images','notebook','prices')
MODEL_LOCATION = os.path.join(module_path, 'models','prices')

# %%
# Load and prepare data
csv_file_path = os.path.join(module_path, "data", "time_series", "time_series_60min_singleindex_filtered.csv")
data_provider = CSVDataProvider(csv_file_path)
data = data_provider.get_data(column_names=["GB_GBN_price_day_ahead"],timestamp_column="utc_timestamp")

# Initialize feature engineer
feature_engineer = FeatureEngineer()

# Load Model
params = {'random_state': 42, "n_estimators": 1000, "max_depth": 6, "learning_rate": 0.1, "objective": "reg:squarederror"}
model=XGBModel(params)

# Train the forecast model
forecaster = ForecastPriceModel(data_provider=data_provider, feature_engineer=feature_engineer, model=model)
train_data = data[data.index.year.isin([2016, 2017, 2018])]
train_data["GB_GBN_price_day_ahead"].interpolate(method="linear", inplace=True)
print(train_data.isna().sum())
forecaster.train(train_data)
# Out:
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\prices\forecasted_price.py:64: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   self.data[self.PRICE_COLUMN].interpolate(method="linear", inplace=True)
# C:\Users\koula\AppData\Local\Temp\ipykernel_22100\2484807568.py:16: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_data["GB_GBN_price_day_ahead"].interpolate(method="linear", inplace=True)
# C:\Users\koula\AppData\Local\Temp\ipykernel_22100\2484807568.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data["GB_GBN_price_day_ahead"].interpolate(method="linear", inplace=True)
# GB_GBN_price_day_ahead    0
# dtype: int64
#   0%|          | 0/24 [00:00<?, ?it/s]
# [0]	validation_0-rmse:26.79616
# c:\Users\koula\miniconda3\envs\OpenEnergy\lib\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [100]	validation_0-rmse:15.46501
# [200]	validation_0-rmse:15.40064
# [300]	validation_0-rmse:15.39170
# [400]	validation_0-rmse:15.38564
# [500]	validation_0-rmse:15.37405
# [600]	validation_0-rmse:15.36796
# [693]	validation_0-rmse:15.37240
# [0]	validation_0-rmse:24.62008
# [100]	validation_0-rmse:16.91650
# [200]	validation_0-rmse:16.82325
# [300]	validation_0-rmse:16.82332
# [400]	validation_0-rmse:16.80177
# [500]	validation_0-rmse:16.78366
# [600]	validation_0-rmse:16.78419
# [643]	validation_0-rmse:16.78700
# [0]	validation_0-rmse:25.62348
# [100]	validation_0-rmse:17.53434
# [200]	validation_0-rmse:17.37509
# [300]	validation_0-rmse:17.31795
# [400]	validation_0-rmse:17.30344
# [500]	validation_0-rmse:17.29893
# [600]	validation_0-rmse:17.28526
# [691]	validation_0-rmse:17.28270
# [0]	validation_0-rmse:23.53320
# [100]	validation_0-rmse:16.31392
# [200]	validation_0-rmse:16.16766
# [300]	validation_0-rmse:16.13270
# [400]	validation_0-rmse:16.10588
# [800]	validation_0-rmse:15.63008
# [900]	validation_0-rmse:15.62676
# [999]	validation_0-rmse:15.62300
# [0]	validation_0-rmse:25.06492
# [100]	validation_0-rmse:18.53798
# [200]	validation_0-rmse:18.46101
# [300]	validation_0-rmse:18.44212
# [400]	validation_0-rmse:18.41497
# [500]	validation_0-rmse:18.39447
# [600]	validation_0-rmse:18.38123
# [700]	validation_0-rmse:18.37611
# [788]	validation_0-rmse:18.37556
# [0]	validation_0-rmse:24.81088
# [100]	validation_0-rmse:17.02608
# [200]	validation_0-rmse:16.87872
# [300]	validation_0-rmse:16.78892
# [400]	validation_0-rmse:16.75228
# [500]	validation_0-rmse:16.72816
# [600]	validation_0-rmse:16.71505
# [700]	validation_0-rmse:16.70240
# [784]	validation_0-rmse:16.70335
# [0]	validation_0-rmse:22.86831
# [100]	validation_0-rmse:14.85221
# [200]	validation_0-rmse:14.66654
# [300]	validation_0-rmse:14.57405
# [400]	validation_0-rmse:14.55818
# [500]	validation_0-rmse:14.53322
# [600]	validation_0-rmse:14.50956
# [700]	validation_0-rmse:14.49976
# [800]	validation_0-rmse:14.49327
# [900]	validation_0-rmse:14.48718
# [999]	validation_0-rmse:14.48467
# [0]	validation_0-rmse:18.53055
# [100]	validation_0-rmse:10.47725
# [200]	validation_0-rmse:10.36061
# [300]	validation_0-rmse:10.29134
# [400]	validation_0-rmse:10.25753
# [500]	validation_0-rmse:10.23412
# [600]	validation_0-rmse:10.20651
# [700]	validation_0-rmse:10.18870
# [800]	validation_0-rmse:10.18221
# [900]	validation_0-rmse:10.17504
# [999]	validation_0-rmse:10.16870
# [0]	validation_0-rmse:22.71528
# [100]	validation_0-rmse:17.16959
# [200]	validation_0-rmse:16.99063
# [300]	validation_0-rmse:16.91218
# [400]	validation_0-rmse:16.88442
# [500]	validation_0-rmse:16.86733
# [600]	validation_0-rmse:16.85677
# [688]	validation_0-rmse:16.85964
# [0]	validation_0-rmse:18.94307
# [100]	validation_0-rmse:11.13234
# [200]	validation_0-rmse:10.95774
# [300]	validation_0-rmse:10.90515
# [400]	validation_0-rmse:10.85892
# [500]	validation_0-rmse:10.83368
# [600]	validation_0-rmse:10.82507
# [700]	validation_0-rmse:10.81428
# [800]	validation_0-rmse:10.80353
# [900]	validation_0-rmse:10.79715
# [999]	validation_0-rmse:10.79472
# [0]	validation_0-rmse:17.37247
# [100]	validation_0-rmse:11.19796
# [200]	validation_0-rmse:11.04557
# [300]	validation_0-rmse:10.98615
# [400]	validation_0-rmse:10.94019
# [500]	validation_0-rmse:10.91367
# [600]	validation_0-rmse:10.90119
# [700]	validation_0-rmse:10.89720
# [800]	validation_0-rmse:10.89122
# [856]	validation_0-rmse:10.89360
# [0]	validation_0-rmse:18.88353
# [100]	validation_0-rmse:13.86751
# [200]	validation_0-rmse:13.78236
# [300]	validation_0-rmse:13.73207
# [400]	validation_0-rmse:13.71852
# [500]	validation_0-rmse:13.70925
# [600]	validation_0-rmse:13.69114
# [700]	validation_0-rmse:13.68146
# [800]	validation_0-rmse:13.66391
# [900]	validation_0-rmse:13.65780
# [985]	validation_0-rmse:13.65915
# [0]	validation_0-rmse:22.12738
# [100]	validation_0-rmse:13.26558
# [200]	validation_0-rmse:13.10900
# [300]	validation_0-rmse:13.04158
# [400]	validation_0-rmse:13.02067
# [500]	validation_0-rmse:13.00009
# [600]	validation_0-rmse:12.98217
# [700]	validation_0-rmse:12.97909
# [800]	validation_0-rmse:12.97229
# [900]	validation_0-rmse:12.96393
# [999]	validation_0-rmse:12.95472
# [0]	validation_0-rmse:24.38954
# [100]	validation_0-rmse:18.00260
# [200]	validation_0-rmse:17.81641
# [300]	validation_0-rmse:17.73254
# [400]	validation_0-rmse:17.68559
# [500]	validation_0-rmse:17.66730
# [600]	validation_0-rmse:17.64518
# [700]	validation_0-rmse:17.63754
# [800]	validation_0-rmse:17.63273
# [900]	validation_0-rmse:17.63011
# [999]	validation_0-rmse:17.62832
# [0]	validation_0-rmse:15.82602
# [100]	validation_0-rmse:10.30655
# [200]	validation_0-rmse:10.18378
# [300]	validation_0-rmse:10.09338
# [400]	validation_0-rmse:10.05668
# [500]	validation_0-rmse:10.04319
# [600]	validation_0-rmse:10.02609
# [700]	validation_0-rmse:10.01284
# [800]	validation_0-rmse:10.00477
# [900]	validation_0-rmse:9.99184
# [999]	validation_0-rmse:9.98626
# [0]	validation_0-rmse:23.55089
# [100]	validation_0-rmse:17.19389
# [200]	validation_0-rmse:17.09939
# [300]	validation_0-rmse:17.04796
# [400]	validation_0-rmse:17.03041
# [500]	validation_0-rmse:17.01044
# [600]	validation_0-rmse:16.99399
# [700]	validation_0-rmse:16.98554
# [800]	validation_0-rmse:16.97826
# [900]	validation_0-rmse:16.97049
# [999]	validation_0-rmse:16.96716
# [0]	validation_0-rmse:20.63203
# [100]	validation_0-rmse:12.40250
# [200]	validation_0-rmse:12.27352
# [300]	validation_0-rmse:12.22820
# [400]	validation_0-rmse:12.20822
# [500]	validation_0-rmse:12.18563
# [600]	validation_0-rmse:12.17249
# [700]	validation_0-rmse:12.16119
# [800]	validation_0-rmse:12.15921
# [834]	validation_0-rmse:12.15947
# Validation MSE: 205.1083017357483

# %%
# Save the model
MODEL_NAME = "price_forecast_model.pkl"
forecaster.save_model(os.path.join(MODEL_LOCATION, MODEL_NAME))

# %%
# Load the model
model = ForecastPriceModel.load_model(os.path.join(MODEL_LOCATION, MODEL_NAME))
pretrained_forecaster = ForecastPriceModel(data_provider=data_provider, feature_engineer=feature_engineer, model=model)
# Out:
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\prices\forecasted_price.py:64: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   self.data[self.PRICE_COLUMN].interpolate(method="linear", inplace=True)

# %%
# Get forecasted prices
forecasted_prices, prices_current_date = pretrained_forecaster.get_prices(datetime(2019, 1, 1))

# Plot the actual values and the forecast
plt.figure(figsize=(10, 6))
plt.plot(prices_current_date, label='Actual')
plt.plot(forecasted_prices, label='Forecast')
plt.title('Forecast vs Actual')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.savefig(os.path.join(IMAGE_SAVING_LOCATION, 'forecast_vs_actual.png'))
plt.show()

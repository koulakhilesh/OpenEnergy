# %% [markdown]
# # Forecast Price Model
#
# This notebook is designed to forecast energy prices using the `ForecastPriceModel` class.
# The model is trained on historical data from 2018 and then used to predict prices for a specific date.
# The actual prices for that date are then compared with the forecasted prices.

# %%
# Import necessary libraries
from datetime import datetime
import os
import sys
import matplotlib.pyplot as plt

# Set up module path
module_path = os.path.abspath(os.path.join('../../'))
if module_path not in sys.path:
    sys.path.append(module_path)

# Import project-specific libraries
from scripts.prices import ForecastPriceModel
from scripts.shared import CSVDataProvider
from scripts.forecast import FeatureEngineer, XGBModel

IMAGE_SAVING_LOCATION = os.path.join(module_path, 'images','notebook','prices')
MODEL_LOCATION = os.path.join(module_path, 'models','prices')

# %%
# Load and prepare data
csv_file_path = os.path.join(module_path, "data", "time_series", "time_series_60min_singleindex_filtered.csv")
data_provider = CSVDataProvider(csv_file_path)
data = data_provider.get_data(column_names=["GB_GBN_price_day_ahead"],timestamp_column="utc_timestamp")

# Initialize feature engineer
feature_engineer = FeatureEngineer()

# Load Model
params = {'random_state': 42, "n_estimators": 1000, "max_depth": 6, "learning_rate": 0.1, "objective": "reg:squarederror"}
model=XGBModel(params)

# Train the forecast model
forecaster = ForecastPriceModel(data_provider=data_provider, feature_engineer=feature_engineer, model=model)
train_data = data[data.index.year.isin([2016, 2017, 2018])]
train_data["GB_GBN_price_day_ahead"].interpolate(method="linear", inplace=True)
print(train_data.isna().sum())
forecaster.train(train_data)
# Out:
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\prices\forecasted_price.py:65: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   self.data[self.PRICE_COLUMN].interpolate(method="linear", inplace=True)
# C:\Users\koula\AppData\Local\Temp\ipykernel_18864\2484807568.py:16: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_data["GB_GBN_price_day_ahead"].interpolate(method="linear", inplace=True)
# C:\Users\koula\AppData\Local\Temp\ipykernel_18864\2484807568.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data["GB_GBN_price_day_ahead"].interpolate(method="linear", inplace=True)
# GB_GBN_price_day_ahead    0
# dtype: int64
#   0%|          | 0/24 [00:00<?, ?it/s]
# [0]	validation_0-rmse:26.79596
# c:\Users\koula\miniconda3\envs\OpenEnergy\lib\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [100]	validation_0-rmse:16.28437
# [200]	validation_0-rmse:16.21539
# [300]	validation_0-rmse:16.19992
# [337]	validation_0-rmse:16.20338
# [0]	validation_0-rmse:24.62008
# [100]	validation_0-rmse:17.13413
# [200]	validation_0-rmse:17.02046
# [300]	validation_0-rmse:17.00647
# [389]	validation_0-rmse:17.01066
# [0]	validation_0-rmse:25.62326
# [100]	validation_0-rmse:18.09585
# [200]	validation_0-rmse:17.92821
# [300]	validation_0-rmse:17.87766
# [400]	validation_0-rmse:17.85542
# [500]	validation_0-rmse:17.82529
# [600]	validation_0-rmse:17.82051
# [700]	validation_0-rmse:17.81659
# [800]	validation_0-rmse:17.80644
# [900]	validation_0-rmse:17.80142
# [999]	validation_0-rmse:17.79791
# [0]	validation_0-rmse:23.53320
# [100]	validation_0-rmse:16.16833
# [200]	validation_0-rmse:15.98723
# [300]	validation_0-rmse:15.90371
# [400]	validation_0-rmse:15.88512
# [500]	validation_0-rmse:15.86257
# [600]	validation_0-rmse:15.85937
# [641]	validation_0-rmse:15.85700
# [0]	validation_0-rmse:22.03534
# [500]	validation_0-rmse:18.31180
# [600]	validation_0-rmse:18.29596
# [700]	validation_0-rmse:18.29399
# [800]	validation_0-rmse:18.28145
# [900]	validation_0-rmse:18.27948
# [999]	validation_0-rmse:18.27632
# [0]	validation_0-rmse:24.81471
# [100]	validation_0-rmse:16.89973
# [200]	validation_0-rmse:16.64061
# [300]	validation_0-rmse:16.55097
# [400]	validation_0-rmse:16.52618
# [500]	validation_0-rmse:16.51685
# [600]	validation_0-rmse:16.49985
# [700]	validation_0-rmse:16.49106
# [800]	validation_0-rmse:16.48927
# [900]	validation_0-rmse:16.48350
# [999]	validation_0-rmse:16.48521
# [0]	validation_0-rmse:22.86928
# [100]	validation_0-rmse:14.72492
# [200]	validation_0-rmse:14.41102
# [300]	validation_0-rmse:14.35252
# [400]	validation_0-rmse:14.31230
# [500]	validation_0-rmse:14.30647
# [600]	validation_0-rmse:14.29153
# [700]	validation_0-rmse:14.28556
# [800]	validation_0-rmse:14.27342
# [900]	validation_0-rmse:14.27160
# [999]	validation_0-rmse:14.26724
# [0]	validation_0-rmse:18.59792
# [100]	validation_0-rmse:12.31845
# [200]	validation_0-rmse:12.15943
# [300]	validation_0-rmse:12.08955
# [400]	validation_0-rmse:12.03710
# [500]	validation_0-rmse:12.01518
# [600]	validation_0-rmse:12.00186
# [700]	validation_0-rmse:11.98861
# [800]	validation_0-rmse:11.98504
# [900]	validation_0-rmse:11.97710
# [999]	validation_0-rmse:11.96934
# [0]	validation_0-rmse:22.69290
# [100]	validation_0-rmse:16.89178
# [200]	validation_0-rmse:16.71738
# [300]	validation_0-rmse:16.65712
# [400]	validation_0-rmse:16.61475
# [500]	validation_0-rmse:16.59215
# [600]	validation_0-rmse:16.57362
# [700]	validation_0-rmse:16.57202
# [800]	validation_0-rmse:16.57081
# [900]	validation_0-rmse:16.56653
# [999]	validation_0-rmse:16.56248
# [0]	validation_0-rmse:18.94315
# [100]	validation_0-rmse:10.66973
# [200]	validation_0-rmse:10.46993
# [300]	validation_0-rmse:10.39691
# [400]	validation_0-rmse:10.35494
# [500]	validation_0-rmse:10.31008
# [600]	validation_0-rmse:10.28782
# [700]	validation_0-rmse:10.27480
# [800]	validation_0-rmse:10.26463
# [900]	validation_0-rmse:10.25603
# [999]	validation_0-rmse:10.24885
# [0]	validation_0-rmse:17.37217
# [100]	validation_0-rmse:10.82176
# [200]	validation_0-rmse:10.64576
# [300]	validation_0-rmse:10.55870
# [400]	validation_0-rmse:10.51356
# [500]	validation_0-rmse:10.48523
# [600]	validation_0-rmse:10.46570
# [700]	validation_0-rmse:10.44726
# [800]	validation_0-rmse:10.44098
# [900]	validation_0-rmse:10.43479
# [999]	validation_0-rmse:10.42850
# [0]	validation_0-rmse:18.88353
# [100]	validation_0-rmse:13.60536
# [200]	validation_0-rmse:13.46169
# [300]	validation_0-rmse:13.38880
# [400]	validation_0-rmse:13.36253
# [500]	validation_0-rmse:13.33425
# [600]	validation_0-rmse:13.31371
# [700]	validation_0-rmse:13.30083
# [800]	validation_0-rmse:13.29381
# [900]	validation_0-rmse:13.28325
# [999]	validation_0-rmse:13.27867
# [0]	validation_0-rmse:22.14255
# [100]	validation_0-rmse:12.50154
# [200]	validation_0-rmse:12.27691
# [300]	validation_0-rmse:12.19570
# [400]	validation_0-rmse:12.15171
# [500]	validation_0-rmse:12.12648
# [600]	validation_0-rmse:12.10935
# [700]	validation_0-rmse:12.09663
# [800]	validation_0-rmse:12.08689
# [900]	validation_0-rmse:12.08265
# [999]	validation_0-rmse:12.07560
# [0]	validation_0-rmse:24.38979
# [100]	validation_0-rmse:17.97547
# [200]	validation_0-rmse:17.78036
# [300]	validation_0-rmse:17.70916
# [400]	validation_0-rmse:17.66945
# [500]	validation_0-rmse:17.64204
# [600]	validation_0-rmse:17.61932
# [700]	validation_0-rmse:17.60739
# [800]	validation_0-rmse:17.59784
# [900]	validation_0-rmse:17.59323
# [999]	validation_0-rmse:17.58641
# [0]	validation_0-rmse:15.82720
# [100]	validation_0-rmse:10.10193
# [200]	validation_0-rmse:9.86261
# [300]	validation_0-rmse:9.78458
# [400]	validation_0-rmse:9.75676
# [500]	validation_0-rmse:9.73053
# [600]	validation_0-rmse:9.71045
# [700]	validation_0-rmse:9.69109
# [800]	validation_0-rmse:9.68006
# [900]	validation_0-rmse:9.67818
# [999]	validation_0-rmse:9.67702
# [0]	validation_0-rmse:23.51807
# [100]	validation_0-rmse:16.84628
# [200]	validation_0-rmse:16.67058
# [300]	validation_0-rmse:16.62896
# [400]	validation_0-rmse:16.58307
# [500]	validation_0-rmse:16.55328
# [600]	validation_0-rmse:16.53706
# [700]	validation_0-rmse:16.53397
# [800]	validation_0-rmse:16.51998
# [900]	validation_0-rmse:16.51128
# [999]	validation_0-rmse:16.50557
# [0]	validation_0-rmse:20.63203
# [100]	validation_0-rmse:11.24146
# [200]	validation_0-rmse:11.12008
# [300]	validation_0-rmse:11.04303
# [400]	validation_0-rmse:11.00131
# [500]	validation_0-rmse:10.97473
# [600]	validation_0-rmse:10.95522
# [700]	validation_0-rmse:10.93942
# [800]	validation_0-rmse:10.92656
# [900]	validation_0-rmse:10.91791
# [999]	validation_0-rmse:10.91100
# Validation MSE: 202.00904141854596

# %%
# Save the model
MODEL_NAME = "price_forecast_model.pkl"
forecaster.save_model(os.path.join(MODEL_LOCATION, MODEL_NAME))

# %%
# Load the model
model = ForecastPriceModel.load_model(os.path.join(MODEL_LOCATION, MODEL_NAME))
pretrained_forecaster = ForecastPriceModel(data_provider=data_provider, feature_engineer=feature_engineer, model=model)
# Out:
# c:\Users\koula\Documents\GitHub\OpenEnergy\scripts\prices\forecasted_price.py:65: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   self.data[self.PRICE_COLUMN].interpolate(method="linear", inplace=True)

# %%
# Get forecasted prices
forecasted_prices, prices_current_date = pretrained_forecaster.get_prices(datetime(2019, 1, 1))

# Plot the actual values and the forecast
plt.figure(figsize=(10, 6))
plt.plot(prices_current_date, label='Actual')
plt.plot(forecasted_prices, label='Forecast')
plt.title('Forecast vs Actual')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.savefig(os.path.join(IMAGE_SAVING_LOCATION, 'forecast_vs_actual.png'))
plt.show()

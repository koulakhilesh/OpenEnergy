# %% [markdown]
# # ⚡ Renewable Portfolio Simulator - OpenEnergy Platform
#
# ## Advanced Multi-Asset Optimization & Simulation
#
# This notebook demonstrates the **Renewable Portfolio Simulator** from OpenEnergy - a comprehensive system for optimizing renewable energy portfolios:
#
# ### 🎯 Core Features
#
# - **🔧 Combined Renewable Simulator** - Integrated solar, wind, and storage modeling
# - **⚡ Portfolio Optimization** - Mathematical optimization using mixed-integer programming
# - **📊 Multi-Asset Coordination** - Synchronized operation of diverse energy assets
# - **💰 Revenue Maximization** - Optimal dispatch strategies for market participation
# - **🔋 Storage Integration** - Smart battery management and dispatch
#
# ### 🌟 Optimization Capabilities
#
# - **📈 Generation Forecasting** - AI-powered renewable output prediction
# - **💸 Price Optimization** - Market price-aware dispatch decisions
# - **⚖️ Constraint Management** - Technical and operational limit enforcement
# - **🎯 Multi-Objective Goals** - Revenue, reliability, and sustainability targets
# - **📊 Scenario Analysis** - Risk assessment and sensitivity analysis

# %%
# Import required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys
import os
from datetime import datetime, timedelta

# Add project root to path
sys.path.append('/Users/akhilesh.koul/Documents/GitHub/OpenEnergy')

# Import OpenEnergy Renewable Simulator
from scripts.renewable_simulator.combined_renewable_simulator import CombinedRenewableSimulator
from scripts.renewable_simulator.renewable_portfolio_optimizer import RenewablePortfolioOptimizer

# Import supporting assets
from scripts.assets.battery import Battery
from scripts.assets.photovoltaic import PVSystem  
from scripts.assets.wind_system import WindSystem

# Configure plotting
plt.style.use('seaborn-v0_8')
sns.set_palette("husl")
plt.rcParams['figure.figsize'] = (14, 8)
plt.rcParams['font.size'] = 10

print("✅ Renewable Portfolio Simulator imported successfully!")
print("⚡ Ready to optimize renewable energy portfolios! 🌱")

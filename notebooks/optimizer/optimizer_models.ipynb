# %% [markdown]
# # 🎯 Optimization Models - OpenEnergy Platform
#
# ## Mathematical Optimization & Scheduling
#
# This notebook demonstrates the **Optimization Models** from OpenEnergy - sophisticated mathematical optimization systems for energy asset management:
#
# ### 🎯 Core Components
#
# - **🔧 Optimization Model** - Mathematical programming framework
# - **📅 Scheduler** - Task scheduling and coordination system
# - **⚖️ Constraint Management** - Technical and operational limit handling
# - **🎯 Objective Functions** - Multi-objective optimization goals
#
# ### 🌟 Optimization Capabilities
#
# - **📊 Mixed-Integer Programming** - Complex decision variable optimization
# - **⚡ Real-time Dispatch** - Dynamic operational scheduling
# - **💰 Revenue Maximization** - Market-aware optimization strategies
# - **🔋 Storage Optimization** - Battery charge/discharge scheduling
# - **⚖️ Multi-Asset Coordination** - Portfolio-wide optimization
#
# ### 🚀 Applications
#
# - **⚡ Energy Dispatch** - Optimal power generation scheduling
# - **💰 Market Participation** - Bidding strategy optimization
# - **🔋 Storage Management** - Battery state-of-charge optimization
# - **📊 Portfolio Balancing** - Multi-asset coordination
# - **⚖️ Constraint Satisfaction** - Technical limit compliance

# %%
# Import required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys
import os
from datetime import datetime, timedelta

# Add project root to path
sys.path.append('/Users/akhilesh.koul/Documents/GitHub/OpenEnergy')

# Import OpenEnergy Optimizer Models
from scripts.optimizer.model import OptimizationModel
from scripts.optimizer.scheduler import Scheduler

# Configure plotting
plt.style.use('seaborn-v0_8')
sns.set_palette("husl")
plt.rcParams['figure.figsize'] = (14, 8)
plt.rcParams['font.size'] = 10

print("✅ Optimization Models imported successfully!")
print("🎯 Ready to optimize energy systems! ⚡")

# %% [markdown]
# # 🌪️ Wind Generation Models - OpenEnergy Platform
#
# ## Advanced Wind Power Forecasting & Modeling
#
# This notebook demonstrates the complete **Wind Generation Models** suite from OpenEnergy:
#
# ### 🎯 Available Models
#
# - **📊 Average Wind Model** - Historical average-based predictions
# - **🔮 Forecasted Wind Model** - Weather-based forecasting
# - **🎲 Simulated Wind Model** - Monte Carlo simulation modeling
# - **🛠️ Wind Data Helper** - Data processing and utilities
#
# ### 🌟 Key Features
#
# - **🌬️ Multiple Forecasting Approaches** - Average, forecasted, and simulated methods
# - **📈 Time Series Analysis** - Historical pattern recognition
# - **🎯 Real-time Calibration** - Dynamic model adjustment
# - **📊 Performance Metrics** - Accuracy assessment and validation
# - **🔧 Data Processing** - Wind speed conversion and power curve modeling

# %%
# Import required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys
import os
from datetime import datetime, timedelta

# Add project root to path
sys.path.append('/Users/akhilesh.koul/Documents/GitHub/OpenEnergy')

# Import OpenEnergy Wind Generation Models
from scripts.wind_generation_models.average_wind_model import AverageWindModel
from scripts.wind_generation_models.forecasted_wind_model import ForecastedWindModel
from scripts.wind_generation_models.simulated_wind_model import SimulatedWindModel
from scripts.wind_generation_models.wind_data_helper import WindDataHelper

# Configure plotting
plt.style.use('seaborn-v0_8')
sns.set_palette("husl")
plt.rcParams['figure.figsize'] = (14, 8)
plt.rcParams['font.size'] = 10

print("✅ Wind Generation Models imported successfully!")
print("🌪️ Ready to forecast wind power generation! 💨")
